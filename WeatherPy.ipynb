# %%
#6.1.4
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#6.1.5 Generate Random World Cities

# %%
pip install citipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from citipy import citipy

# %%
city = citipy.nearest_city(22.99, 120.21)
print(city)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# seymchan ru
# atuona pf
# ishigaki jp
# ushuaia ar
# qaanaaq gl
# castro cl
# arraial do cabo br
# srednekolymsk ru
# srednekolymsk ru
# geraldton ca
# castro cl
# vaitupu wf
# busselton au
# lafia ng
# bonavista ca
# lodja cd
# albany au
# atuona pf
# trincomalee lk
# bredasdorp za
# tiksi ru
# belushya guba ru
# barrow us
# karaul ru
# ponta do sol pt
# katsuura jp
# bluff nz
# saint-philippe re
# sur om
# torbay ca
# mutare zw
# busselton au
# puerto ayora ec
# albany au
# esperance au
# punta arenas cl
# bambous virieux mu
# new norfolk au
# punta arenas cl
# hermanus za
# birao cf
# vardo no
# mataura pf
# puerto ayora ec
# hithadhoo mv
# ribeira grande pt
# vitre fr
# hithadhoo mv
# vaini to
# port hedland au
# pevek ru
# illoqqortoormiut gl
# los llanos de aridane es
# punta arenas cl
# kalabo zm
# kaseda jp
# butaritari ki
# dikson ru
# frontera mx
# castro cl
# mayo ca
# palembang id
# ushuaia ar
# ludvika se
# ribeira grande pt
# busselton au
# dunedin nz
# taolanaro mg
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 600

# %%
#6.2.1 - Overview of API's

# %%
#6.2.2 - Get Started with OpenWeatherMap API
#Get API key for open weather (config.py)
#Download import requests and verify version

# %%
import requests
requests.__version__
# Out:
# '2.22.0'

# %%
#6.2.3. Make an API Call.

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key
print(weather_api_key)
# Out:
# c625fed10534f0ca2dc2b099af094f4e

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c625fed10534f0ca2dc2b099af094f4e

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c625fed10534f0ca2dc2b099af094f4e&q=Boston

# %%
# Added JSON google extension to change format of data
#provided from the URL

# %%
# 6.2.4 Make a Request for Data to an API

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":43.52,"feels_like":27.36,"temp_min":42.01,"temp_max":45,"pressure":1003,"humidity":35},"visibility":16093,"wind":{"speed":19.46,"deg":270,"gust":31.09},"clouds":{"all":75},"dt":1589050856,"sys":{"type":1,"id":3486,"country":"US","sunrise":1589016526,"sunset":1589068355},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
#Change the format to JSON
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 43.52,
#   'feels_like': 27.36,
#   'temp_min': 42.01,
#   'temp_max': 45,
#   'pressure': 1003,
#   'humidity': 35},
#  'visibility': 16093,
#  'wind': {'speed': 19.46, 'deg': 270, 'gust': 31.09},
#  'clouds': {'all': 75},
#  'dt': 1589050856,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1589016526,
#   'sunset': 1589068355},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 43.47,
#   'feels_like': 27.3,
#   'temp_min': 42.01,
#   'temp_max': 45,
#   'pressure': 1003,
#   'humidity': 35},
#  'visibility': 16093,
#  'wind': {'speed': 19.46, 'deg': 270, 'gust': 31.09},
#  'clouds': {'all': 75},
#  'dt': 1589050720,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1589016526,
#   'sunset': 1589068355},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
#Use the sys key to get boston_data
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1589016526,
#  'sunset': 1589068355}

# %%
# Test
boston_data["sys"]["country"]
# Out:
# 'US'

# %%
#Test
boston_data["sys"]
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1589016526,
#  'sunset': 1589068355}

# %%
#Test
boston_data["dt"]
# Out:
# 1589050720

# %%
#Test
boston_data["coord"]["lat"]
# Out:
# 42.36

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 45 35 75 19.46

# %%
#Test
boston_data["main"]["pressure"]
# Out:
# 1003

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 5, 9, 18, 58, 40)

# %%
datetime.utcfromtimestamp(date).strftime('%Y - %m- %d %H: %M: %S')
# Out:
# '2020 - 05- 09 18: 58: 40'

# %%
#6.2.6 Get the City Weather Data

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | seymchan
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | ishigaki
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | srednekolymsk
# Processing Record 9 of Set 1 | geraldton
# Processing Record 10 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | lafia
# Processing Record 13 of Set 1 | bonavista
# Processing Record 14 of Set 1 | lodja
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | trincomalee
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | barrow
# ...

# %%
#6.2.7

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Seymchan  62.88  152.43     27.90        96         100        8.68
# 1           Atuona  -9.80 -139.03     81.14        75          97       18.63
# 2         Ishigaki  24.34  124.16     77.76        89           0       11.41
# 3          Ushuaia -54.80  -68.30     46.40        81          75        4.70
# 4          Qaanaaq  77.48  -69.36     13.12        85           0        2.95
# 5           Castro -24.79  -50.01     68.27        54           0        5.57
# 6  Arraial Do Cabo -22.97  -42.03     75.20        57          20       10.29
# 7    Srednekolymsk  67.45  153.68     27.52        97         100        8.43
# 8        Geraldton -28.77  114.60     60.80        44          65        9.17
# 9        Busselton -33.65  115.33     42.01        71           0        5.48
#
#   Country                 Date
# 0      RU  2020-05-09 19:01:22
# 1      PF  2020-05-09 19:01:22
# ...

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0         Seymchan      RU  2020-05-09 19:01:22  62.88  152.43     27.90
# 1           Atuona      PF  2020-05-09 19:01:22  -9.80 -139.03     81.14
# 2         Ishigaki      JP  2020-05-09 19:00:04  24.34  124.16     77.76
# 3          Ushuaia      AR  2020-05-09 19:01:22 -54.80  -68.30     46.40
# 4          Qaanaaq      GL  2020-05-09 19:01:23  77.48  -69.36     13.12
# 5           Castro      BR  2020-05-09 19:01:23 -24.79  -50.01     68.27
# 6  Arraial Do Cabo      BR  2020-05-09 19:01:23 -22.97  -42.03     75.20
# 7    Srednekolymsk      RU  2020-05-09 19:01:23  67.45  153.68     27.52
# 8        Geraldton      AU  2020-05-09 19:01:23 -28.77  114.60     60.80
# 9        Busselton      AU  2020-05-09 18:57:30 -33.65  115.33     42.01
#
#    Humidity  Cloudiness  Wind Speed
# 0        96         100        8.68
# 1        75          97       18.63
# 2        89           0       11.41
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#6.3.1 Plot Latitude vs. Temperature

# %%
city_data_df.head(10)
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0         Seymchan      RU  2020-05-09 19:01:22  62.88  152.43     27.90
# 1           Atuona      PF  2020-05-09 19:01:22  -9.80 -139.03     81.14
# 2         Ishigaki      JP  2020-05-09 19:00:04  24.34  124.16     77.76
# 3          Ushuaia      AR  2020-05-09 19:01:22 -54.80  -68.30     46.40
# 4          Qaanaaq      GL  2020-05-09 19:01:23  77.48  -69.36     13.12
# 5           Castro      BR  2020-05-09 19:01:23 -24.79  -50.01     68.27
# 6  Arraial Do Cabo      BR  2020-05-09 19:01:23 -22.97  -42.03     75.20
# 7    Srednekolymsk      RU  2020-05-09 19:01:23  67.45  153.68     27.52
# 8        Geraldton      AU  2020-05-09 19:01:23 -28.77  114.60     60.80
# 9        Busselton      AU  2020-05-09 18:57:30 -33.65  115.33     42.01
#
#    Humidity  Cloudiness  Wind Speed
# 0        96         100        8.68
# 1        75          97       18.63
# 2        89           0       11.41
# ...

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1589051148.546112

# %%
today = time.strftime("%x")
today
# Out:
# '05/09/20'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
#6.3.2 Plot Latitude vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
#6.3.3 Plot Latitude vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
#6.3.4 Plot Latitude vs. Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
#6.4.1 Linear Regression PRACTICE

# %%
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Customizing the linear regression
# If it is desired to leave a calculation out, simply use
# a comma and underscore, (slope, _, _, p_value, _) for example

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
#6.4.2 Correlation : Lattidue and Max Temp

# %%
#Create a Linear Regression Function

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.  
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#This doesn't show anything until we call the function
#with the 5 parameters

# %%
#Return data from a particular index
index13 = city_data_df.loc[13]
index13
# Out:
# City                       Albany
# Country                        US
# Date          2020-05-09 19:00:05
# Lat                          42.6
# Lng                        -73.97
# Max Temp                    44.01
# Humidity                       40
# Cloudiness                     92
# Wind Speed                   5.01
# Name: 13, dtype: object

# %%
#Get all the latitudes in the nothern hemisphere, i.e. >=0
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 547     True
# 548    False
# 549    False
# 550     True
# 551     True
# Name: Lat, Length: 552, dtype: bool

# %%
city_data_df.head(5)
# Out:
#        City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 0  Seymchan      RU  2020-05-09 19:01:22  62.88  152.43     27.90        96
# 1    Atuona      PF  2020-05-09 19:01:22  -9.80 -139.03     81.14        75
# 2  Ishigaki      JP  2020-05-09 19:00:04  24.34  124.16     77.76        89
# 3   Ushuaia      AR  2020-05-09 19:01:22 -54.80  -68.30     46.40        81
# 4   Qaanaaq      GL  2020-05-09 19:01:23  77.48  -69.36     13.12        85
#
#    Cloudiness  Wind Speed
# 0         100        8.68
# 1          97       18.63
# 2           0       11.41
# 3          75        4.70
# 4           0        2.95

# %%
#Combine the two to return data from the index that meets
#the criteria, Index city is in Northern Hemisphere
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >=0)]
northern_hemi_df.head(5)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0        Seymchan      RU  2020-05-09 19:01:22  62.88  152.43     27.90
# 2        Ishigaki      JP  2020-05-09 19:00:04  24.34  124.16     77.76
# 4         Qaanaaq      GL  2020-05-09 19:01:23  77.48  -69.36     13.12
# 7   Srednekolymsk      RU  2020-05-09 19:01:23  67.45  153.68     27.52
# 10          Lafia      NG  2020-05-09 19:01:24   8.48    8.52     79.70
#
#     Humidity  Cloudiness  Wind Speed
# 0         96         100        8.68
# 2         89           0       11.41
# 4         85           0        2.95
# 7         97         100        8.43
# 10        71         100        0.94

# %%
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]
southern_hemi_df.head()
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 1           Atuona      PF  2020-05-09 19:01:22  -9.80 -139.03     81.14
# 3          Ushuaia      AR  2020-05-09 19:01:22 -54.80  -68.30     46.40
# 5           Castro      BR  2020-05-09 19:01:23 -24.79  -50.01     68.27
# 6  Arraial Do Cabo      BR  2020-05-09 19:01:23 -22.97  -42.03     75.20
# 8        Geraldton      AU  2020-05-09 19:01:23 -28.77  114.60     60.80
#
#    Humidity  Cloudiness  Wind Speed
# 1        75          97       18.63
# 3        81          75        4.70
# 5        54           0        5.57
# 6        57          20       10.29
# 8        44          65        9.17

# %%
#Perform Linear Regression on Max Temp for Northern Hemi
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 
                       'Max Temp', (10, 40))

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Maximum Temperature',
                       'Max Temp', (-50, 90))

# %%
#6.4.3 Find Correlation; Latitude and Percent Humidity
#Use the same plot_linear_regression function from earlier
#and simply change the column values to Lat and Humidity

# %%
#Latitude and Humidity for Northern Hemi
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression (x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Humidity',
                       '% Humidity', (40,10))

# %%
#Latitude and Humidity for Souther  Hemi
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression (x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Humidity',
                       '% Humidity', (40,10))

# %%
#6.4.4 Find Correlation : Latitude and Percent Cloudiness
#refactoring same linear regression code as before

# %%
#Latitude and Percent Cloudiness for Nothern Hemi
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression (x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Cloudiness',
                       '% Cloudiness', (40,10))

# %%
#Latitude and Percent Cloudiness for Southern Hemi
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 
                      'Linear Regression on the Southern Hemisphere for % Cloudiness',
                       '% Cloudiness', (40,10))

# %%
#6.4.5 Find Correlation between Latitude and Wind Speed
#using same refactored code

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Wind Speed',
                       'Wind Speed',(40,35))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Wind Speed',
                       'Wind Speed',(-50,35))

# %%
#6.5.1 Set up Google Maps and Places API

# %%
#6.5.2 Create Heatmaps for Weather Parameters

# %%
pip install gmaps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key
import gmaps.datasets

# %%
print(g_key)
# Out:
# AIzaSyBBsviK145YfXgY9qlgl4kJUeN7zOYh8Fc

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID      City Country                 Date    Lat     Lng  Max Temp  \
# 0        0  Seymchan      RU  2020-05-09 19:01:22  62.88  152.43     27.90
# 1        1    Atuona      PF  2020-05-09 19:01:22  -9.80 -139.03     81.14
# 2        2  Ishigaki      JP  2020-05-09 19:00:04  24.34  124.16     77.76
# 3        3   Ushuaia      AR  2020-05-09 19:01:22 -54.80  -68.30     46.40
# 4        4   Qaanaaq      GL  2020-05-09 19:01:23  77.48  -69.36     13.12
#
#    Humidity  Cloudiness  Wind Speed
# 0        96         100        8.68
# 1        75          97       18.63
# 2        89           0       11.41
# 3        81          75        4.70
# 4        85           0        2.95

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Google heatmaps does not print negative numbers so we have to use
#a for loop to iterate through the list and map only the (+) 's
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
locations = city_data_df[["Lat", "Lng"]]
max_temp = city_data_df["Max Temp"]
fig = gmaps.figure()
#additional code change
heat_layer = gmaps.heatmap_layer(locations, weights=temps)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Use list comprehension with the heat_layer function
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
locations = city_data_df[["Lat", "Lng"]]
max_temp = city_data_df["Max Temp"]
fig = gmaps.figure()
#additional code change
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Add a center and zoom level
#fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
locations = city_data_df[["Lat", "Lng"]]
max_temp = city_data_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#additional code change
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Modify dissipation
#heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
locations = city_data_df[["Lat", "Lng"]]
max_temp = city_data_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#additional code change
heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create a Percent Humidity Heatmap
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create a Percent Cloudiness Heatmap
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create a Wind Speed Heatmap
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#6.5.3 Get Vacation Criteria

# %%
#Ask Customer for temp. values using the input() function
#We also want this to be a float datat type so we nest input inside
min_temp = float(input("What is the minimum temperature you would like for your trip?"))
max_temp = float(input("What is the maximum temperature you would like for your trip?"))
# Out:
# What is the minimum temperature you would like for your trip?75
# What is the maximum temperature you would like for your trip?90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country                 Date    Lat     Lng  \
# 1         1           Atuona      PF  2020-05-09 19:01:22  -9.80 -139.03
# 2         2         Ishigaki      JP  2020-05-09 19:00:04  24.34  124.16
# 6         6  Arraial Do Cabo      BR  2020-05-09 19:01:23 -22.97  -42.03
# 10       10            Lafia      NG  2020-05-09 19:01:24   8.48    8.52
# 14       14      Trincomalee      LK  2020-05-09 19:01:24   8.57   81.23
# 22       22              Sur      OM  2020-05-09 19:01:26  22.57   59.53
# 25       25     Puerto Ayora      EC  2020-05-09 19:01:26  -0.74  -90.35
# 28       28  Bambous Virieux      MU  2020-05-09 19:01:27 -20.34   57.76
# 34       34        Hithadhoo      MV  2020-05-09 19:00:37  -0.60   73.08
# 37       37            Vaini      TO  2020-05-09 19:01:28 -21.20 -175.20
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      81.14        75          97       18.63
# 2      77.76        89           0       11.41
# ...

# %%
#Determine if there are any null values in the preferred_cities_df
preferred_cities_df.count()
#If null values were present, we would need to use the dropna()
#method at the end of the filtering statement
# Out:
# City_ID       159
# City          159
# Country       159
# Date          159
# Lat           159
# Lng           159
# Max Temp      159
# Humidity      159
# Cloudiness    159
# Wind Speed    159
# dtype: int64

# %%
#6.5.4 Map Vacation Criteria

# %%
#Use preferred_cities_df to create a hotel_df which we'll use to map
#potential vacation spots for our clients.
hotel_df = preferred_cities_df[["City","Country","Max Temp","Lat","Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp    Lat     Lng Hotel Name
# 1            Atuona      PF     81.14  -9.80 -139.03
# 2          Ishigaki      JP     77.76  24.34  124.16
# 6   Arraial Do Cabo      BR     75.20 -22.97  -42.03
# 10            Lafia      NG     79.70   8.48    8.52
# 14      Trincomalee      LK     81.48   8.57   81.23
# 22              Sur      OM     86.36  22.57   59.53
# 25     Puerto Ayora      EC     86.00  -0.74  -90.35
# 28  Bambous Virieux      MU     75.20 -20.34   57.76
# 34        Hithadhoo      MV     84.79  -0.60   73.08
# 37            Vaini      TO     78.80 -21.20 -175.20

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping")
# Out:
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping

# %%
hotel_df.head(10)
# Out:
#                City Country  Max Temp    Lat     Lng  \
# 1            Atuona      PF     81.14  -9.80 -139.03
# 2          Ishigaki      JP     77.76  24.34  124.16
# 6   Arraial Do Cabo      BR     75.20 -22.97  -42.03
# 10            Lafia      NG     79.70   8.48    8.52
# 14      Trincomalee      LK     81.48   8.57   81.23
# 22              Sur      OM     86.36  22.57   59.53
# 25     Puerto Ayora      EC     86.00  -0.74  -90.35
# 28  Bambous Virieux      MU     75.20 -20.34   57.76
# 34        Hithadhoo      MV     84.79  -0.60   73.08
# 37            Vaini      TO     78.80 -21.20 -175.20
#
#                        Hotel Name
# 1                     Villa Enata
# 2   Hotel Peace Land Ishigakijima
# 6             Pousada Porto Praia
# 10        Low Cost Housing Estate
# 14                 Welcombe Hotel
# 22                Sur Plaza Hotel
# 25      Finch Bay Galapagos Hotel
# 28                 Casa Tia Villa
# 34              Scoop Guest House
# ...

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, 
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, 
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
